# %% [markdown]
# # Series01-Python-Git using Git and Github

# %%
#
import numpy as np

import matplotlib.pyplot as plt

# Read the ECG data from the text file ( this put the data not visualized but in a table format)
ecg_raw = np.loadtxt('data/ECGu.txt')
print(ecg_raw)
# Plot the ECG signal
plt.plot(ecg_raw)
plt.title('ECG') 
plt.xlabel('Time (in ms)')
plt.ylabel('Amplitude (in μV)') 
plt.grid()
plt.show()
# Out:
# [[-275. -119. -119.]
#  [-275. -119. -119.]
#  [-275. -118. -121.]
#  ...
#  [  -4.  -83.   21.]
#  [  -9.  -88.   31.]
#  [ -16.  -96.   33.]]

# %%
sampling_frequency=1000 #Frequecy in Hz
T=1/sampling_frequency #Period between 2 samples in s
N=len(ecg_raw)
start=0
stop=(N-1)*T
t= np.linspace(start,stop,N,)

plt.plot(t,ecg_raw)
plt.title('ECG SIGNAL')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Step 1: Rescale the ECG data to standard units (millivolts)
# The A/D converter gain is 1024 µV per unit, so we convert the raw data to mV
ecg_data_mV = ecg_raw * 1024e-6  # Convert raw data to millivolts

plt.plot(t,ecg_data_mV)
plt.title('ECG Signal with Proper Units')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude (mV)')
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\Chahine\AppData\Local\Temp\ipykernel_19708\3820830093.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
